# %% [markdown]
# <a href="https://colab.research.google.com/github/akemiyamashita/Trainable_Segmentation/blob/master/readdicom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydicom -U
# Out:
# ...
#     100% |████████████████████████████████| 7.0MB 4.9MB/s
# ...

# %%
import glob, pylab, pandas as pd
import pydicom, numpy as np

# %%
print(data)
# Out:
# (d8ff, e0ff) Private tag data                    UN: b'IF\x00\x01\x02\x01\x01,\x01,\x00\x00\xff\xc4\x01\xa2\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa
# ...

# %%
dcm_file = '0000a175-0e68-4ca4-b1af-167204a7e0bc.dcm' 
dcm_data = pydicom.read_file(dcm_file,force=True)
print(dcm_data)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.10118.1517874346.924223
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: PA'
# (0010, 0010) Patient's Name                      PN: '0000a175-0e68-4ca4-b1af-167204a7e0bc'
# (0010, 0020) Patient ID                          LO: '0000a175-0e68-4ca4-b1af-167204a7e0bc'
# (0010, 0030) Patient's Birth Date                DA: ''
# ...

# %%
cr_file = '37072259_CR_20181023_001.dcm' 
cr_data = pydicom.read_file(cr_file,force=True)
print(cr_data)
# Out:
# (d8ff, e0ff) Private tag data                    UN: b'IF\x00\x01\x02\x01\x01,\x01,\x00\x00\xff\xc4\x01\xa2\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa
# ...

# %%
import numpy as np

im = dcm_data.pixel_array
print(type(im))
print(im.dtype)
print(im.shape)
# Out:
# <class 'numpy.ndarray'>
# uint8
# (1024, 1024)

# %%
from pylab import *

# %%
pylab.imshow(im, cmap=pylab.cm.gist_gray)
pylab.axis('off')
# Out:
# (-0.5, 1023.5, 1023.5, -0.5)

# %%
cr = cr_data.pixel_array
print(type(cr))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-08aa2dafff4b> in <module>()
# ----> 1 cr = cr_data.pixel_array
#       2 print(type(cr))
#
# /usr/local/lib/python3.6/dist-packages/pydicom/dataset.py in __getattr__(self, name)
#     550         if tag is None:  # `name` isn't a DICOM element keyword
#     551             # Try the base class attribute getter (fix for issue 332)
# --> 552             return super(Dataset, self).__getattribute__(name)
#     553         tag = Tag(tag)
#     554         if tag not in self._dict:  # DICOM DataElement not in the Dataset
#
# /usr/local/lib/python3.6/dist-packages/pydicom/dataset.py in pixel_array(self)
#     947             The Pixel Data (7FE0,0010) as a NumPy ndarray.
#     948         """
# --> 949         self.convert_pixel_data()
#     950         return self._pixel_array
#     951
#
# ...
